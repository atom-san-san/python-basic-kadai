# %%
# 台形の各辺の長さ（cm）
upper_base = 10   # 上辺
lower_base = 20   # 下辺
height = 5        # 高さ

# 台形の面積の計算
area = (upper_base + lower_base) * height / 2

# 結果の表示
print(f"台形の面積は {area} 平方センチメートルです。")
# Out:
# 台形の面積は 75.0 平方センチメートルです。

# %% [markdown]
# # 新しいセクション
