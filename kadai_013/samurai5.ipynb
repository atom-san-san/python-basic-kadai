# %%
def add_two_arguments(price, tax):
    #与えられた引数priceと引数を加算し、変数totalへ代入する
    total = price * (1 + tax / 100)
    #変数totalの値を出力する
    print(f"{total}円")

#関数を呼び出し、引数として金額と税額を渡す
add_two_arguments(110,10);
# Out:
# 121.00000000000001円
